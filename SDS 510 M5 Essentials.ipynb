# %%
import pandas as pd
import requests
import numpy as np
import re
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.naive_bayes import MultinomialNB 
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score 
from datetime import datetime
import string
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 12
#      10 from datetime import datetime
#      11 import string
# ---> 12 import metrics
#
# ModuleNotFoundError: No module named 'metrics'

# %%
# load the data file 
url = "https://www.dropbox.com/scl/fi/7rbdzltgef1gl3tmhv6il/jeopardy.json?rlkey=fa3jeovy07nsfpl01hufvxkz3&st=vnwpphp6&dl=1"
response = requests.get(url)

with open("jeopardy.json", "wb") as f :
    f.write(response.content)

# %%
# load the json file into a df
df = pd.read_json("jeopardy.json") 
print(df.columns)
print(df.head())

'''
columns: category, air_date, question, value, answer, round, show_number
'''
# Out:
# Index(['category', 'air_date', 'question', 'value', 'answer', 'round',
#        'show_number'],
#       dtype='object')
#                           category    air_date  \
# 0                          HISTORY  2004-12-31
# 1  ESPN's TOP 10 ALL-TIME ATHLETES  2004-12-31
# 2      EVERYBODY TALKS ABOUT IT...  2004-12-31
# 3                 THE COMPANY LINE  2004-12-31
# 4              EPITAPHS & TRIBUTES  2004-12-31
#
#                                             question value       answer  \
# 0  'For the last 8 years of his life, Galileo was...  $200   Copernicus
# 1  'No. 2: 1912 Olympian; football star at Carlis...  $200   Jim Thorpe
# 2  'The city of Yuma in this state has a record a...  $200      Arizona
# 3  'In 1963, live on "The Art Linkletter Show", t...  $200  McDonald\'s
# 4  'Signer of the Dec. of Indep., framer of the C...  $200   John Adams
#
#        round  show_number
# 0  Jeopardy!         4680
# 1  Jeopardy!         4680
# 2  Jeopardy!         4680
# 3  Jeopardy!         4680
# 4  Jeopardy!         4680

# %%
# remove the special characters in the value column 
df['value_clean'] = (
    df['value']
    .replace('[$,]', '', regex = True)
    .replace('None',0)
    .replace('',0)
    .fillna(0)
    .astype(float) 
)

# check what are the values so I could classify them 
print(df['value_clean'].describe()) 
median_value = 600
# the meidan value I could use to classify is 600
# Out:
# count    216930.000000
# mean        739.988476
# std         639.822693
# min           0.000000
# 25%         400.000000
# 50%         600.000000
# 75%        1000.000000
# max       18000.000000
# Name: value_clean, dtype: float64

# %%
# create the binary label for values
df['high_value'] = df['value_clean'].apply(lambda x: 1 if x >= median_value else 0) 

# check the class balance 
df['high_value'].value_counts(normalize=True) # the dataset is quit well balanced
# Out:
# high_value
# 1    0.524907
# 0    0.475093
# Name: proportion, dtype: float64

# %%
# clean the question text 
def clean_text(text):
    text = str(text).lower()
    text = text.translate(str.maketrans('', '', string.punctuation))
    return text 

df['clean_question'] = df['question'].apply(clean_text)

# %%
# split into train and test set
x = df['clean_question']
y = df['high_value']

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 123)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'high_value'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 6
#       3 y = df['high_value']
#       5 x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 123)
# ----> 6 print(x_train['high_value'])
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'high_value'

# %%
# tfidf
tfidf_vectorize = TfidfVectorizer(use_idf=True)
x_train_tf = tfidf_vectorize.fit_transform(x_train)
x_test_tf = tfidf_vectorize.transform(x_test)

# %%
# NB model
naive_bayes = MultinomialNB()
naive_bayes.fit(x_train_tf, y_train)
predictions = naive_bayes.predict(x_test_tf)

# %%
print('Accueracy: ', accuracy_score(y_test, predictions)) 
# I got an accueracy of 56.42%
# Out:
# Accueracy:  0.5642136706433353
#                                category    air_date  \
# 0                               HISTORY  2004-12-31
# 1       ESPN's TOP 10 ALL-TIME ATHLETES  2004-12-31
# 2           EVERYBODY TALKS ABOUT IT...  2004-12-31
# 3                      THE COMPANY LINE  2004-12-31
# 4                   EPITAPHS & TRIBUTES  2004-12-31
# ...                                 ...         ...
# 216925                   RIDDLE ME THIS  2006-05-11
# 216926                        "T" BIRDS  2006-05-11
# 216927           AUTHORS IN THEIR YOUTH  2006-05-11
# 216928                       QUOTATIONS  2006-05-11
# 216929                   HISTORIC NAMES  2006-05-11
#
#                                                  question  value  \
# 0       'For the last 8 years of his life, Galileo was...   $200
# 1       'No. 2: 1912 Olympian; football star at Carlis...   $200
# 2       'The city of Yuma in this state has a record a...   $200
# 3       'In 1963, live on "The Art Linkletter Show", t...   $200
# 4       'Signer of the Dec. of Indep., framer of the C...   $200
# ...                                                   ...    ...
# 216925  'This Puccini opera turns on the solution to 3...  $2000
# 216926  'In North America this term is properly applie...  $2000
# 216927  'In Penny Lane, where this "Hellraiser" grew u...  $2000
# 216928  'From Ft. Sill, Okla. he made the plea, Arizon...  $2000
# 216929  'A silent movie title includes the last name o...   None
#
#                                 answer             round  show_number  \
# 0                           Copernicus         Jeopardy!         4680
# 1                           Jim Thorpe         Jeopardy!         4680
# 2                              Arizona         Jeopardy!         4680
# 3                          McDonald\'s         Jeopardy!         4680
# 4                           John Adams         Jeopardy!         4680
# ...                                ...               ...          ...
# 216925                        Turandot  Double Jeopardy!         4999
# 216926                      a titmouse  Double Jeopardy!         4999
# 216927                    Clive Barker  Double Jeopardy!         4999
# 216928                        Geronimo  Double Jeopardy!         4999
# 216929  Grigori Alexandrovich Potemkin   Final Jeopardy!         4999
#
#         value_clean  high_value  \
# 0             200.0           0
# 1             200.0           0
# 2             200.0           0
# 3             200.0           0
# 4             200.0           0
# ...             ...         ...
# 216925       2000.0           1
# 216926       2000.0           1
# 216927       2000.0           1
# 216928       2000.0           1
# 216929          0.0           0
#
#                                            clean_question
# 0       for the last 8 years of his life galileo was u...
# 1       no 2 1912 olympian football star at carlisle i...
# 2       the city of yuma in this state has a record av...
# 3       in 1963 live on the art linkletter show this c...
# 4       signer of the dec of indep framer of the const...
# ...                                                   ...
# 216925  this puccini opera turns on the solution to 3 ...
# 216926  in north america this term is properly applied...
# 216927  in penny lane where this hellraiser grew up th...
# 216928  from ft sill okla he made the plea arizona is ...
# 216929  a silent movie title includes the last name of...
#
# [216930 rows x 10 columns]

# %%
''' 
Below is the Essential Badge 
'''

# %%
from sklearn.svm import LinearSVC

# %%
svm_model = LinearSVC()
svm_model.fit(x_train_tf, y_train)
# Out:
# LinearSVC()

# %%
svm_preds = svm_model.predict(x_test_tf)
print("SVM Accuracy:" , accuracy_score(y_test, svm_preds))
# Out:
# SVM Accuracy: 0.5568012095956336

# %%
''' 
The Support Vector Machine (SVM) achieved 55.68% accuracy, which is lower than NB model. Which I assume that is due to the nature
of the dataset that cause NB outperformed SVM
'''

# %%
'''
Below I will be using question length to predict the vlaues useing a NB model
'''

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report

# %%
df['question_length'] = df['clean_question'].apply(lambda x: len(x.split()))

# %%
x2 = df[['question_length']]  # only using question length
y2 = df['high_value']

x2_train, x2_test, y2_train, y2_test = train_test_split(x2, y2, test_size=0.2, random_state=123)

# %%
nb_model = GaussianNB()
nb_model.fit(x2_train, y2_train)

y2_pred = nb_model.predict(x2_test)

# %%
print("Accuracy:", accuracy_score(y2_test, y2_pred))
print(classification_report(y2_test, y2_pred))
# Out:
# Accuracy: 0.5289033328723551
#               precision    recall  f1-score   support
#
#            0       0.50      0.62      0.55     20526
#            1       0.57      0.45      0.50     22860
#
#     accuracy                           0.53     43386
#    macro avg       0.53      0.53      0.53     43386
# weighted avg       0.54      0.53      0.53     43386

# %%
'''
Based on the accuracy report we could conclude that question length has some predictive power but still not a strong one. If we look at 
the recall value the model is missing a lot of high_value questions.

# %%
nb_model = MultinomialNB() 
nb_model.fit(x2_train, y2_train)

y2_pred = nb_model.predict(x2_test)
